# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Requirements
# * The dataset can be downloaded from [this Kaggle competition](https://www.kaggle.com/c/ieee-fraud-detection).
# * In addition to the [Anaconda](https://www.anaconda.com) libraries, you need to install `altair`, `vega_datasets`, `pyod` and `scikit-learn` version 0.24 or higher.
# * You also need to set up an AWS account and install `awscli` and `sagemaker-python-sdk`.

# %%
import gc
import multiprocessing
import os
import pickle
import warnings
import sklearn
import numpy as np
import pandas as pd
import altair as alt
from scipy.interpolate import interp1d
from sklearn.compose import make_column_transformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from sklearn.manifold import TSNE
from sklearn.metrics import (
    average_precision_score,
    precision_recall_curve,
    roc_auc_score,
    roc_curve,
)
from sklearn.model_selection import train_test_split
from category_encoders import HelmertEncoder
from pyod.models.copod import COPOD
from pyod.models.iforest import IForest

warnings.filterwarnings(action="ignore")

# %%
def dump_pickle(file_path, obj):
    with open(file_path, "wb") as file:
        pickle.dump(obj, file)


def load_pickle(file_path):
    with open(file_path, "rb") as file:
        obj = pickle.load(file)
    return obj


def cast_data_type(series):
    column_type = series.dtype
    if column_type != np.object:
        val_min = series.min()
        val_max = series.max()
        if column_type == np.int_:
            if val_min > np.iinfo(np.int8).min and val_max < np.iinfo(np.int8).max:
                series = series.astype(np.int8)
            elif val_min > np.iinfo(np.int16).min and val_max < np.iinfo(np.int16).max:
                series = series.astype(np.int16)
            elif val_min > np.iinfo(np.int32).min and val_max < np.iinfo(np.int32).max:
                series = series.astype(np.int32)
            elif val_min > np.iinfo(np.int64).min and val_max < np.iinfo(np.int64).max:
                series = series.astype(np.int64)
        else:
            if (
                val_min > np.finfo(np.float16).min
                and val_max < np.finfo(np.float16).max
            ):
                series = series.astype(np.float16)
            elif (
                val_min > np.finfo(np.float32).min
                and val_max < np.finfo(np.float32).max
            ):
                series = series.astype(np.float32)
            else:
                series = series.astype(np.float64)
    return series


def reduce_mem_usage(df):
    mem_usage = df.memory_usage().sum() / 1024 ** 2
    print(f"Memory usage of dataframe is {mem_usage:0.2f} MB.")
    df = df.apply(cast_data_type)
    opt_mem_usage = df.memory_usage().sum() / 1024 ** 2
    print(f"Memory usage after optimization is {opt_mem_usage:0.2f} MB.")
    print(
        f"Decreased by {(100 * (mem_usage - opt_mem_usage) / mem_usage):0.2f}%."
    )
    return df


def str_to_int(x):
    return x if pd.isnull(x) else str(int(x))

# %% [markdown]
# #### Data Loading from Local Directory
# The Kaggle dataset was saved in the local directory `~/data/ieee-fraud-detection` in advance.

# %%
DATA_DIR = "../../data/ieee-fraud-detection"

# %%
train_identity = pd.read_csv(os.path.join(DATA_DIR, "train_identity.csv"))
train_transaction = pd.read_csv(os.path.join(DATA_DIR, "train_transaction.csv"))
test_identity = pd.read_csv(os.path.join(DATA_DIR, "test_identity.csv"))
test_transaction = pd.read_csv(os.path.join(DATA_DIR, "test_transaction.csv"))

df_train = pd.merge(train_transaction, train_identity, on="TransactionID", how="left")
df_test = pd.merge(test_transaction, test_identity, on="TransactionID", how="left")
df_test = df_test.rename(columns={f"id-{i:02d}": f"id_{i:02d}" for i in range(1, 39)})

# %%
del train_identity, train_transaction, test_identity, test_transaction
_ = gc.collect()

# %%
print(f"Train dataset has {df_train.shape[0]} rows and {df_train.shape[1]} columns.")
print(f"Test dataset has {df_test.shape[0]} rows and {df_test.shape[1]} columns.")
# Out:
# Train dataset has 590540 rows and 434 columns.
# Test dataset has 506691 rows and 433 columns.

# %%
print(f"The fraud rate is {df_train['isFraud'].mean():.2%}.")
# Out:
# The fraud rate is 3.50%.

# %%
df_train = reduce_mem_usage(df_train)
df_test = reduce_mem_usage(df_test)
# Out:
# Memory usage of dataframe is 1959.88 MB.
# Memory usage after optimization is 650.48 MB.
# Decreased by 66.81%.
# Memory usage of dataframe is 1677.73 MB.
# Memory usage after optimization is 565.37 MB.
# Decreased by 66.30%.

# %% [markdown]
# # Exploratory Data Analysis

# %%
prop_of_missing_values = (
    df_train[df_train.columns.difference(["TransactionID", "isFraud"])].isnull().sum()
    / df_train.shape[0]
).reset_index()
prop_of_missing_values.columns = ["feature", "prop_of_missing_values"]
source = prop_of_missing_values.sample(100, random_state=42)

highlight = alt.selection(
    type="single", on="mouseover", fields=["feature"], nearest=True
)
bars = (
    alt.Chart(source)
    .mark_bar()
    .encode(
        x=alt.X("feature:N", axis=alt.Axis(title="Feature"), sort="-y"),
        y=alt.Y(
            "prop_of_missing_values:Q", axis=alt.Axis(title="Percentage", format=".0%")
        ),
        color=alt.Color("prop_of_missing_values:Q", legend=None),
        opacity=alt.condition(~highlight, alt.value(1.0), alt.value(0.5)),
        tooltip=["feature:N", alt.Tooltip("prop_of_missing_values:Q", format=".2%")],
    )
    .add_selection(highlight)
)
bars.properties(
    title="Proportions of Missing Values", width=1200, height=200
).configure_axisX(labelAngle=-45, labelFontSize=8)
# Out:
# alt.Chart(...)

# %%
cat_features = pd.Index(
    [
        "ProductCD",
        "addr1",
        "addr2",
        "P_emaildomain",
        "R_emaildomain",
        "DeviceType",
        "DeviceInfo",
    ]
    + [f"card{i}" for i in range(1, 7)]
    + [f"M{i}" for i in range(1, 10)]
    + [f"id_{i}" for i in range(12, 39)]
)
num_features = df_train.columns.difference(
    pd.Index(["TransactionID", "TransactionDT", "isFraud"]) | cat_features
)
all_features = cat_features | num_features

# %%
print(
    f"There are {len(cat_features)} categorical features and {len(num_features)} numeric features."
)
# Out:
# There are 49 categorical features and 382 numeric features.

# %%
int_cat_features = df_train[cat_features].select_dtypes("number").columns
df_train[int_cat_features] = df_train[int_cat_features].applymap(str_to_int)

int_cat_features = df_test[cat_features].select_dtypes("number").columns
df_test[int_cat_features] = df_test[int_cat_features].applymap(str_to_int)

# %%
source = df_train[cat_features].nunique().reset_index()
source.columns = ["feature", "cardinality"]

bars = alt.Chart(source).mark_bar().encode(
    x=alt.X("feature:N", axis=alt.Axis(title="Feature"), sort="-y"),
    y=alt.Y("cardinality:Q", axis=alt.Axis(title="Count")),
    tooltip=["feature:N", "cardinality:Q"]
)
bars.properties(title="Cardinalities of Categorical Features", width=1000, height=200).configure_axisX(labelAngle=-45)
# Out:
# alt.Chart(...)

# %%
def plot_histogram(values, index, bins=20, bar_size=15, height=200, n_digits=0):
    hist, bin_edges = np.histogram(values, bins=bins)
    source = (
        pd.DataFrame(hist, index=bin_edges[:-1], columns=["count"])
        .reset_index()
        .rename(columns={index: "count", "index": index})
    )
    stats = pd.DataFrame(
        {
            "mean": [round(values.mean(), 2)],
            "median": [round(np.quantile(values, 0.5), 2)],
        }
    )
    eps = 0.02

    bars = (
        alt.Chart(source)
        .transform_joinaggregate(total_count="sum(count)")
        .transform_calculate(pecent_of_total="datum.count / datum.total_count")
        .mark_bar(size=bar_size)
        .encode(
            x=alt.X(
                f"{index}:Q",
                axis=alt.Axis(title=None, format=f".{n_digits}f"),
                scale=alt.Scale(
                    domain=[bin_edges[0] - eps, bin_edges[-1] + eps], nice=False
                ),
            ),
            y=alt.Y("pecent_of_total:Q", axis=alt.Axis(title=None, format=".0%")),
            tooltip=[
                alt.Tooltip(f"{index}:Q", format=f".{n_digits}f"),
                alt.Tooltip("count:Q", format=".0f"),
            ],
        )
    )
    rule_mean = (
        alt.Chart(stats)
        .mark_rule(color="#ff7f0e", size=1.5, strokeDash=[3, 2])
        .encode(x="mean:Q", tooltip=["mean", "mean:Q"])
    )
    rule_median = (
        alt.Chart(stats)
        .mark_rule(color="#2ca02c", size=1.5, strokeDash=[3, 2])
        .encode(x="median:Q", tooltip=["median", "median:Q"])
    )
    return (bars + rule_mean + rule_median).properties(
        title=f"Histogram of '{index}'", height=height
    )

# %%
np.random.seed(42)
missing_value_ratios = df_train[num_features].isnull().sum() / df_train.shape[0]
value_counts = df_train[num_features].nunique()
selected_features = num_features[(missing_value_ratios < 0.5) & (value_counts > 99)]
selected_features = np.random.permutation(selected_features)[:20]

# %%
charts = []
for feature in selected_features:
    charts.append(
        plot_histogram(
            df_train[feature].dropna(),
            feature,
            bins=20,
            bar_size=12.5,
            height=100,
            n_digits=0,
        )
    )

rows = []
for i, chart in enumerate(charts):
    if (i % 3 == 2) or (i == len(charts) - 1):
        rows.append(alt.HConcatChart(hconcat=charts[i - (i % 3) : i + 1]))
alt.VConcatChart(vconcat=rows[:3]).configure_axisY(
    labelAlign="left", labelLimit=30, labelPadding=30
).configure_axisX(labelAngle=-45)
# Out:
# alt.VConcatChart(...)

# %%
corr_matrix = df_train[selected_features].corr()
source = corr_matrix.stack().reset_index()
source.columns = ["feature_x", "feature_y", "correlation"]

base = alt.Chart(source).encode(
    x=alt.X("feature_x:N", axis=alt.Axis(ticks=False, title="Feature")),
    y=alt.Y("feature_y:N", axis=alt.Axis(ticks=False, title="Feature")),
)
text = base.mark_text(size=10).encode(
    text=alt.Text("correlation", format=".0%"),
    color=alt.condition(
        alt.datum.correlation > 0.5, alt.value("white"), alt.value("black")
    ),
)
heatmap = base.mark_rect().encode(
    color=alt.Color(
        "correlation:Q", legend=alt.Legend(title="Correlation", titleFontSize=9)
    )
)
(heatmap + text).properties(
    title="Correlation Matrix", width=500, height=500
).configure_axisX(labelAngle=-45)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # Data Splitting and Preprocessing

# %%
df_train[cat_features] = df_train[cat_features].astype("str")
df_test[cat_features] = df_test[cat_features].astype("str")

df_X_train, df_X_valid, df_y_train, df_y_valid = train_test_split(
    df_train[all_features],
    df_train["isFraud"],
    test_size=0.2,
    random_state=42,
    stratify=df_train["isFraud"],
)

# %%
n_jobs = int(0.75 * multiprocessing.cpu_count())
cat_pipeline = make_pipeline(
    OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=np.nan),
    SimpleImputer(strategy="constant", fill_value=-1),
    HelmertEncoder(drop_invariant=True),
    StandardScaler(),
)
num_pipeline = make_pipeline(StandardScaler(), SimpleImputer(strategy="median"))
transformer = make_column_transformer(
    (cat_pipeline, cat_features), (num_pipeline, num_features)
)

X_train = transformer.fit_transform(df_X_train)
X_valid = transformer.transform(df_X_valid)

# %% [markdown]
# ### Data Visualization with t-SNE

# %%
tsne = TSNE(
    n_components=2,
    perplexity=50.0,
    early_exaggeration=12.0,
    learning_rate=200.0,
    random_state=42,
    n_jobs=n_jobs,
)
manifold = tsne.fit_transform(X_valid[:5000])

# %%
source = pd.DataFrame(
    np.c_[manifold, df_y_valid.iloc[:5000].values],
    columns=["feature_x", "feature_y", "is_fraud"],
)
source["is_fraud"] = source["is_fraud"].map(lambda x: str(int(x)))

brush = alt.selection(type="interval")
base = alt.Chart(source).add_selection(brush)
points = base.mark_point(size=5).encode(
    x=alt.X("feature_x", title=None),
    y=alt.Y("feature_y", title=None),
    color=alt.condition(
        brush,
        alt.Color("is_fraud:N", legend=alt.Legend(title="Fraudulent", titleFontSize=9)),
        alt.value("grey"),
    ),
)
tick_axis = alt.Axis(labels=False, domain=False, ticks=False)
x_ticks = base.mark_tick().encode(
    alt.X("feature_x", title="Feature", axis=tick_axis),
    alt.Y("is_fraud", title=None, axis=tick_axis),
    color=alt.condition(brush, "is_fraud", alt.value("lightgrey")),
)
y_ticks = base.mark_tick().encode(
    alt.X("is_fraud", title=None, axis=tick_axis),
    alt.Y("feature_y", title="Feature", axis=tick_axis),
    color=alt.condition(brush, "is_fraud", alt.value("lightgrey")),
)
(y_ticks | (points & x_ticks)).properties(
    title="Scatter Plot of Manifold with t-SNE"
).configure_title(anchor="middle")
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# # Model Training and Prediction
# ## Fitting and Prediction with PyOD Isolation Forest and COPOD

# %%
# %%time
if_estimator = IForest(
    n_estimators=100, behaviour="new", n_jobs=n_jobs, random_state=42
)
_ = if_estimator.fit(X_train)
if_scores = if_estimator.predict_proba(X_valid)
# Out:
# CPU times: user 8min 4s, sys: 2min 50s, total: 10min 54s
# Wall time: 5min 49s

# %%
# %%time
cop_estimator = COPOD() 
_ = cop_estimator.fit(X_train)
cop_scores = cop_estimator.predict_proba(X_valid)
# Out:
# CPU times: user 3min 45s, sys: 1min 23s, total: 5min 9s
# Wall time: 4min 54s

# %% [markdown]
# ## Fitting with Amazon SageMaker Random Cut Forest

# %%
import boto3
import botocore
import sagemaker
from sagemaker import RandomCutForest

print(f"<VERSION>\nsagemaker: {sagemaker.__version__}")
# Out:
# <VERSION>
# sagemaker: 2.39.0.post0

# %%
def check_bucket_permission(bucket):
    permission = False
    try:
        boto3.Session().client("s3").head_bucket(Bucket=bucket)
    except botocore.exceptions.ParamValidationError:
        print(
            "Hey! You either forgot to specify your S3 bucket \
            or you gave your bucket an invalid name!"
        )
    except botocore.exceptions.ClientError as error:
        if error.response["Error"]["Code"] == "403":
            print(f"Hey! You don't have permission to access the bucket, {bucket}.")
        elif error.response["Error"]["Code"] == "404":
            print(f"Hey! Your bucket, {bucket}, doesn't exist!")
        else:
            raise
    else:
        permission = True
    return permission

# %%
sagemaker_session = sagemaker.Session()
BUCKET = sagemaker_session.default_bucket()
PREFIX = "ieee-fraud-detection"
region = boto3.Session().region_name
role = sagemaker.get_execution_role()

if check_bucket_permission(BUCKET):
    print(f"Input/output will be stored in: s3://{'_'.join(BUCKET.split('-')[:-1])}_.../{PREFIX}")
# Out:
# Input/output will be stored in: s3://sagemaker_us_east_1_.../ieee-fraud-detection

# %%
rcf_estimator = RandomCutForest(
    role=role,
    instance_count=1,
    instance_type="ml.m4.xlarge",
    data_location=f"s3://{BUCKET}/{PREFIX}/train/",
    output_path=f"s3://{BUCKET}/{PREFIX}/models",
    num_samples_per_tree=512,
    num_trees=100,
)
_ = rcf_estimator.fit(rcf_estimator.record_set(X_train))
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-08-02 15:32:37 Starting - Starting the training job...
# 2021-08-02 15:33:00 Starting - Launching requested ML instancesProfilerReport-1627918354: InProgress
# ...
# 2021-08-02 15:33:40 Starting - Preparing the instances for training.........
# 2021-08-02 15:35:20 Downloading - Downloading input data......
# 2021-08-02 15:36:34 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [08/02/2021 15:36:40 INFO 140310658893632] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-conf.json: {'num_samples_per_tree': 256, 'num_trees': 100, 'force_dense': 'true', 'eval_metrics': ['accuracy', 'precision_recall_fscore'], 'epochs': 1, 'mini_batch_size': 1000, '_log_level': 'info', '_kvstore': 'dist_async', '_num_kv_servers': 'auto', '_num_gpus': 'auto', '_tuning_objective_metric': '', '_ftp_port': 8999}
# [08/02/2021 15:36:40 INFO 140310658893632] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'num_trees': '100', 'num_samples_per_tree': '512', 'feature_dim': '431', 'mini_batch_size': '1000'}
# [08/02/2021 15:36:40 INFO 140310658893632] Final configuration: {'num_samples_per_tree': '512', 'num_trees': '100', 'force_dense': 'true', 'eval_metrics': ['accuracy', 'precision_recall_fscore'], 'epochs': 1, 'mini_batch_size': '1000', '_log_level': 'info', '_kvstore': 'dist_async', '_num_kv_servers': 'auto', '_num_gpus': 'auto', '_tuning_objective_metric': '', '_ftp_port': 8999, 'feature_dim': '431'}
# [08/02/2021 15:36:40 WARNING 140310658893632] Loggers have already been setup.
# [08/02/2021 15:36:40 INFO 140310658893632] Launching parameter server for role scheduler
# [08/02/2021 15:36:40 INFO 140310658893632] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-123-37.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2021-08-02-15-32-34-850', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:...:training-job/randomcutforest-2021-08-02-15-32-34-850', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/399e51cc-b509-4b1e-a9f1-2e8972d3f9e6', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'AWS_REGION': 'us-east-1', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/f1aaa529-f69d-4d6b-b6f8-6f36372521a2', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/f1aaa529-f69d-4d6b-b6f8-6f36372521a2', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}
# [08/02/2021 15:36:40 INFO 140310658893632] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-123-37.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2021-08-02-15-32-34-850', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:...:training-job/randomcutforest-2021-08-02-15-32-34-850', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/399e51cc-b509-4b1e-a9f1-2e8972d3f9e6', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'AWS_REGION': 'us-east-1', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/f1aaa529-f69d-4d6b-b6f8-6f36372521a2', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/f1aaa529-f69d-4d6b-b6f8-6f36372521a2', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'scheduler', 'DMLC_PS_ROOT_URI': '10.2.123.37', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# [08/02/2021 15:36:40 INFO 140310658893632] Launching parameter server for role server
# [08/02/2021 15:36:40 INFO 140310658893632] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-123-37.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2021-08-02-15-32-34-850', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:...:training-job/randomcutforest-2021-08-02-15-32-34-850', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/399e51cc-b509-4b1e-a9f1-2e8972d3f9e6', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'AWS_REGION': 'us-east-1', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/f1aaa529-f69d-4d6b-b6f8-6f36372521a2', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/f1aaa529-f69d-4d6b-b6f8-6f36372521a2', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}
# [08/02/2021 15:36:40 INFO 140310658893632] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-123-37.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2021-08-02-15-32-34-850', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:...:training-job/randomcutforest-2021-08-02-15-32-34-850', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/399e51cc-b509-4b1e-a9f1-2e8972d3f9e6', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'AWS_REGION': 'us-east-1', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/f1aaa529-f69d-4d6b-b6f8-6f36372521a2', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/f1aaa529-f69d-4d6b-b6f8-6f36372521a2', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'server', 'DMLC_PS_ROOT_URI': '10.2.123.37', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# [08/02/2021 15:36:40 INFO 140310658893632] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-123-37.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2021-08-02-15-32-34-850', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:...:training-job/randomcutforest-2021-08-02-15-32-34-850', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/399e51cc-b509-4b1e-a9f1-2e8972d3f9e6', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'AWS_REGION': 'us-east-1', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/f1aaa529-f69d-4d6b-b6f8-6f36372521a2', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/f1aaa529-f69d-4d6b-b6f8-6f36372521a2', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '10.2.123.37', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# Process 33 is a shell:scheduler.
# Process 44 is a shell:server.
# Process 1 is a worker.
# [08/02/2021 15:36:40 INFO 140310658893632] Using default worker.
# [08/02/2021 15:36:40 INFO 140310658893632] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [08/02/2021 15:36:40 INFO 140310658893632] Checkpoint loading and saving are disabled.
# [08/02/2021 15:36:40 INFO 140310658893632] Verifying hyperparamemters...
# [08/02/2021 15:36:40 INFO 140310658893632] Hyperparameters are correct.
# [08/02/2021 15:36:40 INFO 140310658893632] Validating that feature_dim agrees with dimensions in training data...
# [08/02/2021 15:36:40 INFO 140310658893632] feature_dim is correct.
# [08/02/2021 15:36:40 INFO 140310658893632] Validating memory limits...
# [08/02/2021 15:36:40 INFO 140310658893632] Available memory in bytes: 15178960896
# [08/02/2021 15:36:40 INFO 140310658893632] Estimated sample size in bytes: 353075200
# [08/02/2021 15:36:40 INFO 140310658893632] Estimated memory needed to build the forest in bytes: 882688000
# [08/02/2021 15:36:40 INFO 140310658893632] Memory limits validated.
# [08/02/2021 15:36:40 INFO 140310658893632] Starting cluster sharing facilities...
# [08/02/2021 15:36:40 INFO 140310658893632] Create Store: dist_async
# [08/02/2021 15:36:40 INFO 140308864038656] >>> starting FTP server on 0.0.0.0:8999, pid=1 <<<
# [I 21-08-02 15:36:40] >>> starting FTP server on 0.0.0.0:8999, pid=1 <<<
# [I 21-08-02 15:36:40] poller: <class 'pyftpdlib.ioloop.Epoll'>
# [08/02/2021 15:36:40 INFO 140308864038656] poller: <class 'pyftpdlib.ioloop.Epoll'>
# [I 21-08-02 15:36:40] masquerade (NAT) address: None
# [I 21-08-02 15:36:40] passive ports: None
# [08/02/2021 15:36:40 INFO 140308864038656] masquerade (NAT) address: None
# [08/02/2021 15:36:40 INFO 140308864038656] passive ports: None
# [08/02/2021 15:36:40 INFO 140308864038656] use sendfile(2): True
# [I 21-08-02 15:36:40] use sendfile(2): True
# [08/02/2021 15:36:41 INFO 140310658893632] Cluster sharing facilities started.
# [08/02/2021 15:36:41 INFO 140310658893632] Verifying all workers are accessible...
# [08/02/2021 15:36:41 INFO 140310658893632] All workers accessible.
# [08/02/2021 15:36:41 INFO 140310658893632] Initializing Sampler...
# [08/02/2021 15:36:41 INFO 140310658893632] Sampler correctly initialized.
# #metrics {"StartTime": 1627918600.1736941, "EndTime": 1627918601.67513, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 1471.2028503417969, "count": 1, "min": 1471.2028503417969, "max": 1471.2028503417969}}}
#
# #metrics {"StartTime": 1627918601.675348, "EndTime": 1627918601.6754084, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [2021-08-02 15:36:41.688] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 1513, "num_examples": 1, "num_bytes": 3476000}
# [08/02/2021 15:36:41 INFO 140310658893632] Sampling training data...
# [2021-08-02 15:36:53.196] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 11507, "num_examples": 473, "num_bytes": 1642173632}
# [08/02/2021 15:36:53 INFO 140310658893632] Sampling training data completed.
# #metrics {"StartTime": 1627918601.6752777, "EndTime": 1627918613.4432654, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"epochs": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "update.time": {"sum": 11755.036115646362, "count": 1, "min": 11755.036115646362, "max": 11755.036115646362}}}
#
# [08/02/2021 15:36:53 INFO 140310658893632] Early stop condition met. Stopping training.
# [08/02/2021 15:36:53 INFO 140310658893632] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1627918601.6881886, "EndTime": 1627918613.4437037, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 472432.0, "count": 1, "min": 472432, "max": 472432}, "Total Batches Seen": {"sum": 473.0, "count": 1, "min": 473, "max": 473}, "Max Records Seen Between Resets": {"sum": 472432.0, "count": 1, "min": 472432, "max": 472432}, "Max Batches Seen Between Resets": {"sum": 473.0, "count": 1, "min": 473, "max": 473}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 472432.0, "count": 1, "min": 472432, "max": 472432}, "Number of Batches Since Last Reset": {"sum": 473.0, "count": 1, "min": 473, "max": 473}}}
#
# [08/02/2021 15:36:53 INFO 140310658893632] #throughput_metric: host=algo-1, train throughput=40187.63881233475 records/second
# [08/02/2021 15:36:53 INFO 140310658893632] Master node: building Random Cut Forest...
# [08/02/2021 15:36:53 INFO 140310658893632] Gathering samples...
# [08/02/2021 15:36:53 INFO 140310658893632] 51200 samples gathered
# [08/02/2021 15:36:53 INFO 140310658893632] Building Random Cut Forest...
# [08/02/2021 15:36:55 INFO 140310658893632] Random Cut Forest built:
#
# ForestInfo{num_trees: 100, num_samples_in_forest: 51200, num_samples_per_tree: 512, sample_dim: 431, shingle_size: 1, trees_num_nodes: [939, 945, 957, 947, 939, 943, 937, 953, 961, 943, 959, 947, 963, 945, 959, 961, 927, 949, 947, 965, 945, 949, 951, 951, 967, 961, 971, 931, 957, 935, 931, 965, 943, 963, 933, 953, 947, 957, 939, 949, 959, 943, 923, 953, 929, 933, 945, 955, 957, 941, 945, 957, 963, 945, 939, 939, 917, 953, 953, 931, 965, 939, 955, 939, 939, 943, 947, 949, 967, 953, 939, 927, 961, 949, 953, 941, 937, 963, 937, 919, 965, 947, 947, 941, 945, 955, 959, 963, 937, 939, 937, 955, 957, 949, 933, 945, 957, 937, 947, 953, ], trees_depth: [53, 58, 51, 66, 47, 62, 52, 52, 59, 39, 67, 55, 81, 50, 48, 51, 53, 35, 43, 50, 39, 73, 50, 56, 49, 44, 42, 52, 52, 58, 54, 50, 55, 49, 51, 59, 58, 55, 54, 53, 57, 54, 50, 41, 38, 60, 53, 53, 52, 46, 48, 44, 39, 58, 50, 42, 50, 38, 54, 42, 53, 39, 44, 33, 64, 64, 51, 55, 49, 58, 50, 53, 45, 42, 52, 58, 51, 52, 56, 57, 52, 56, 45, 43, 66, 37, 41, 43, 51, 64, 55, 47, 52, 53, 46, 42, 67, 57, 55, 52, ], max_num_nodes: 971, min_num_nodes: 917, avg_num_nodes: 947, max_tree_depth: 81, min_tree_depth: 33, avg_tree_depth: 51, mem_size: 661762784}
# #metrics {"StartTime": 1627918613.4433737, "EndTime": 1627918615.836929, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"fit_model.time": {"sum": 2323.3304023742676, "count": 1, "min": 2323.3304023742676, "max": 2323.3304023742676}, "model.bytes": {"sum": 661762784.0, "count": 1, "min": 661762784, "max": 661762784}, "finalize.time": {"sum": 2392.820358276367, "count": 1, "min": 2392.820358276367, "max": 2392.820358276367}}}
#
# [08/02/2021 15:37:27 INFO 140310658893632] Master node: Serializing the RandomCutForest model
# #metrics {"StartTime": 1627918615.8370745, "EndTime": 1627918647.6323268, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"serialize_model.time": {"sum": 31795.180559158325, "count": 1, "min": 31795.180559158325, "max": 31795.180559158325}}}
#
# [08/02/2021 15:37:27 INFO 140310658893632] Test data is not provided.
# #metrics {"StartTime": 1627918647.6324239, "EndTime": 1627918647.6325598, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 27.612924575805664, "count": 1, "min": 27.612924575805664, "max": 27.612924575805664}, "totaltime": {"sum": 47499.531745910645, "count": 1, "min": 47499.531745910645, "max": 47499.531745910645}}}
#
#
# 2021-08-02 15:37:41 Uploading - Uploading generated training model
# 2021-08-02 15:38:42 Completed - Training job completed
# Training seconds: 215
# Billable seconds: 215

# %% [markdown]
# #### Uploading Validation Set to S3 Bucket

# %%
np.savetxt(os.path.join(DATA_DIR, "X_valid.csv"), X_valid, delimiter=",", fmt="%i")
valid_data_uri = sagemaker_session.upload_data(
    os.path.join(DATA_DIR, "X_valid.csv"), bucket=BUCKET, key_prefix=f"{PREFIX}/valid"
)

# %% [markdown]
# ## Defining Transformer and Prediction

# %%
# %%time
rcf_transformer = rcf_estimator.transformer(
    instance_count=1,
    instance_type="ml.m4.xlarge",
    output_path=f"s3://{BUCKET}/{PREFIX}/pred",
)
_ = rcf_transformer.transform(
    data=valid_data_uri, content_type="text/csv", split_type="Line"
)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# ..........................................Docker entrypoint called with argument(s): serve
# Running default environment configuration script
# [08/02/2021 15:47:36 INFO 140698560526144] loaded entry point class algorithm.serve.server_config:config_api
# [08/02/2021 15:47:36 INFO 140698560526144] loading entry points
# [08/02/2021 15:47:36 INFO 140698560526144] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [08/02/2021 15:47:36 INFO 140698560526144] loaded request iterator application/json
# [08/02/2021 15:47:36 INFO 140698560526144] loaded request iterator application/jsonlines
# [08/02/2021 15:47:36 INFO 140698560526144] loaded request iterator application/x-recordio-protobuf
# [08/02/2021 15:47:36 INFO 140698560526144] loaded request iterator text/csv
# [08/02/2021 15:47:36 INFO 140698560526144] loaded response encoder application/json
# [08/02/2021 15:47:36 INFO 140698560526144] loaded response encoder application/jsonlines
# [08/02/2021 15:47:36 INFO 140698560526144] loaded response encoder application/x-recordio-protobuf
# [08/02/2021 15:47:36 INFO 140698560526144] loaded response encoder text/csv
# [08/02/2021 15:47:36 INFO 140698560526144] loaded entry point class algorithm:model
# [08/02/2021 15:47:36 INFO 140698560526144] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [08/02/2021 15:47:36 INFO 140698560526144] Number of server workers: 1
# [08/02/2021 15:47:36 INFO 140698560526144] loading model...
# [08/02/2021 15:47:47 INFO 140698560526144] Random Cut Forest model loaded.
#
# ForestInfo{num_trees: 100, num_samples_in_forest: 51200, num_samples_per_tree: 512, sample_dim: 431, shingle_size: 1, trees_num_nodes: [939, 945, 957, 947, 939, 943, 937, 953, 961, 943, 959, 947, 963, 945, 959, 961, 927, 949, 947, 965, 945, 949, 951, 951, 967, 961, 971, 931, 957, 935, 931, 965, 943, 963, 933, 953, 947, 957, 939, 949, 959, 943, 923, 953, 929, 933, 945, 955, 957, 941, 945, 957, 963, 945, 939, 939, 917, 953, 953, 931, 965, 939, 955, 939, 939, 943, 947, 949, 967, 953, 939, 927, 961, 949, 953, 941, 937, 963, 937, 919, 965, 947, 947, 941, 945, 955, 959, 963, 937, 939, 937, 955, 957, 949, 933, 945, 957, 937, 947, 953, ], trees_depth: [53, 58, 51, 66, 47, 62, 52, 52, 59, 39, 67, 55, 81, 50, 48, 51, 53, 35, 43, 50, 39, 73, 50, 56, 49, 44, 42, 52, 52, 58, 54, 50, 55, 49, 51, 59, 58, 55, 54, 53, 57, 54, 50, 41, 38, 60, 53, 53, 52, 46, 48, 44, 39, 58, 50, 42, 50, 38, 54, 42, 53, 39, 44, 33, 64, 64, 51, 55, 49, 58, 50, 53, 45, 42, 52, 58, 51, 52, 56, 57, 52, 56, 45, 43, 66, 37, 41, 43, 51, 64, 55, 47, 52, 53, 46, 42, 67, 57, 55, 52, ], max_num_nodes: 971, min_num_nodes: 917, avg_num_nodes: 947, max_tree_depth: 81, min_tree_depth: 33, avg_tree_depth: 51, mem_size: 661762784}
# #metrics {"StartTime": 1627919256.451954, "EndTime": 1627919267.3565152, "Dimensions": {}, "Metrics": {"model.bytes": {"sum": 661762784.0, "count": 1, "min": 661762784, "max": 661762784}, "deserialize_model.time": {"sum": 10459.01370048523, "count": 1, "min": 10459.01370048523, "max": 10459.01370048523}}}
#
# [08/02/2021 15:47:47 INFO 140698560526144] ...model loaded.
# [2021-08-02 15:47:47 +0000] [1] [INFO] Starting gunicorn 20.0.4
# [2021-08-02 15:47:47 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2021-08-02 15:47:47 +0000] [1] [INFO] Using worker: sync
# [2021-08-02 15:47:47 +0000] [42] [INFO] Booting worker with pid: 42
# #metrics {"StartTime": 1627919267.3568528, "EndTime": 1627919267.4562573, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"execution_parameters.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# 2021-08-02T15:47:47.461:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# #metrics {"StartTime": 1627919267.4563813, "EndTime": 1627919287.977996, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"evaluate.time": {"sum": 19882.744550704956, "count": 1, "min": 19882.744550704956, "max": 19882.744550704956}}}
#
# #metrics {"StartTime": 1627919287.9781044, "EndTime": 1627919288.0022113, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 6.759881973266602, "count": 1, "min": 6.759881973266602, "max": 6.759881973266602}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# #metrics {"StartTime": 1627919267.4563813, "EndTime": 1627919287.977996, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"evaluate.time": {"sum": 19882.744550704956, "count": 1, "min": 19882.744550704956, "max": 19882.744550704956}}}
#
# #metrics {"StartTime": 1627919287.9781044, "EndTime": 1627919288.0022113, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 6.759881973266602, "count": 1, "min": 6.759881973266602, "max": 6.759881973266602}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# #metrics {"StartTime": 1627919308.3430364, "EndTime": 1627919328.8133373, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"evaluate.time": {"sum": 19969.97332572937, "count": 1, "min": 19969.97332572937, "max": 19969.97332572937}}}
#
# #metrics {"StartTime": 1627919328.8134508, "EndTime": 1627919328.8354278, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 4.5642852783203125, "count": 1, "min": 4.5642852783203125, "max": 4.5642852783203125}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# #metrics {"StartTime": 1627919308.3430364, "EndTime": 1627919328.8133373, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"evaluate.time": {"sum": 19969.97332572937, "count": 1, "min": 19969.97332572937, "max": 19969.97332572937}}}
#
# #metrics {"StartTime": 1627919328.8134508, "EndTime": 1627919328.8354278, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 4.5642852783203125, "count": 1, "min": 4.5642852783203125, "max": 4.5642852783203125}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# #metrics {"StartTime": 1627919349.1706936, "EndTime": 1627919369.3540158, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"evaluate.time": {"sum": 19680.595636367798, "count": 1, "min": 19680.595636367798, "max": 19680.595636367798}}}
#
# #metrics {"StartTime": 1627919349.1706936, "EndTime": 1627919369.3540158, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"evaluate.time": {"sum": 19680.595636367798, "count": 1, "min": 19680.595636367798, "max": 19680.595636367798}}}
#
# #metrics {"StartTime": 1627919369.3541236, "EndTime": 1627919369.3755257, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 4.323244094848633, "count": 1, "min": 4.323244094848633, "max": 4.323244094848633}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# #metrics {"StartTime": 1627919369.3541236, "EndTime": 1627919369.3755257, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 4.323244094848633, "count": 1, "min": 4.323244094848633, "max": 4.323244094848633}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# #metrics {"StartTime": 1627919389.603553, "EndTime": 1627919389.624761, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 4.270792007446289, "count": 1, "min": 4.270792007446289, "max": 4.270792007446289}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# #metrics {"StartTime": 1627919389.603553, "EndTime": 1627919389.624761, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 4.270792007446289, "count": 1, "min": 4.270792007446289, "max": 4.270792007446289}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# #metrics {"StartTime": 1627919389.6248446, "EndTime": 1627919409.934288, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"evaluate.time": {"sum": 19817.253351211548, "count": 1, "min": 19817.253351211548, "max": 19817.253351211548}}}
#
# #metrics {"StartTime": 1627919409.9343944, "EndTime": 1627919409.9553592, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 4.164218902587891, "count": 1, "min": 4.164218902587891, "max": 4.164218902587891}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# #metrics {"StartTime": 1627919389.6248446, "EndTime": 1627919409.934288, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"evaluate.time": {"sum": 19817.253351211548, "count": 1, "min": 19817.253351211548, "max": 19817.253351211548}}}
#
# #metrics {"StartTime": 1627919409.9343944, "EndTime": 1627919409.9553592, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 4.164218902587891, "count": 1, "min": 4.164218902587891, "max": 4.164218902587891}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# #metrics {"StartTime": 1627919430.2726734, "EndTime": 1627919450.6225178, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"evaluate.time": {"sum": 19859.601497650146, "count": 1, "min": 19859.601497650146, "max": 19859.601497650146}}}
#
# #metrics {"StartTime": 1627919450.6226332, "EndTime": 1627919450.6436903, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 4.046440124511719, "count": 1, "min": 4.046440124511719, "max": 4.046440124511719}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# #metrics {"StartTime": 1627919430.2726734, "EndTime": 1627919450.6225178, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"evaluate.time": {"sum": 19859.601497650146, "count": 1, "min": 19859.601497650146, "max": 19859.601497650146}}}
#
# #metrics {"StartTime": 1627919450.6226332, "EndTime": 1627919450.6436903, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 4.046440124511719, "count": 1, "min": 4.046440124511719, "max": 4.046440124511719}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# #metrics {"StartTime": 1627919470.7921138, "EndTime": 1627919491.0769587, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"evaluate.time": {"sum": 19792.44327545166, "count": 1, "min": 19792.44327545166, "max": 19792.44327545166}}}
#
# #metrics {"StartTime": 1627919491.0770655, "EndTime": 1627919491.0979507, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 4.044055938720703, "count": 1, "min": 4.044055938720703, "max": 4.044055938720703}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# #metrics {"StartTime": 1627919470.7921138, "EndTime": 1627919491.0769587, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"evaluate.time": {"sum": 19792.44327545166, "count": 1, "min": 19792.44327545166, "max": 19792.44327545166}}}
#
# #metrics {"StartTime": 1627919491.0770655, "EndTime": 1627919491.0979507, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 4.044055938720703, "count": 1, "min": 4.044055938720703, "max": 4.044055938720703}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# #metrics {"StartTime": 1627919511.2621741, "EndTime": 1627919531.6845844, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"evaluate.time": {"sum": 19937.647819519043, "count": 1, "min": 19937.647819519043, "max": 19937.647819519043}}}
#
# #metrics {"StartTime": 1627919511.2621741, "EndTime": 1627919531.6845844, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"evaluate.time": {"sum": 19937.647819519043, "count": 1, "min": 19937.647819519043, "max": 19937.647819519043}}}
#
# #metrics {"StartTime": 1627919531.6847038, "EndTime": 1627919531.7060807, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 4.128217697143555, "count": 1, "min": 4.128217697143555, "max": 4.128217697143555}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# #metrics {"StartTime": 1627919531.6847038, "EndTime": 1627919531.7060807, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 4.128217697143555, "count": 1, "min": 4.128217697143555, "max": 4.128217697143555}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# #metrics {"StartTime": 1627919551.9527454, "EndTime": 1627919551.9741137, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 4.22215461730957, "count": 1, "min": 4.22215461730957, "max": 4.22215461730957}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# #metrics {"StartTime": 1627919551.9527454, "EndTime": 1627919551.9741137, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 4.22215461730957, "count": 1, "min": 4.22215461730957, "max": 4.22215461730957}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# #metrics {"StartTime": 1627919551.9741912, "EndTime": 1627919572.2588153, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"evaluate.time": {"sum": 19796.101808547974, "count": 1, "min": 19796.101808547974, "max": 19796.101808547974}}}
#
# #metrics {"StartTime": 1627919551.9741912, "EndTime": 1627919572.2588153, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"evaluate.time": {"sum": 19796.101808547974, "count": 1, "min": 19796.101808547974, "max": 19796.101808547974}}}
#
# #metrics {"StartTime": 1627919572.258926, "EndTime": 1627919572.280217, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 3.9882659912109375, "count": 1, "min": 3.9882659912109375, "max": 3.9882659912109375}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# #metrics {"StartTime": 1627919572.258926, "EndTime": 1627919572.280217, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 3.9882659912109375, "count": 1, "min": 3.9882659912109375, "max": 3.9882659912109375}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# #metrics {"StartTime": 1627919592.4638617, "EndTime": 1627919592.48495, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 4.26030158996582, "count": 1, "min": 4.26030158996582, "max": 4.26030158996582}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# #metrics {"StartTime": 1627919592.4638617, "EndTime": 1627919592.48495, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 4.26030158996582, "count": 1, "min": 4.26030158996582, "max": 4.26030158996582}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
#
# #metrics {"StartTime": 1627919592.4850276, "EndTime": 1627919600.835462, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"evaluate.time": {"sum": 8150.918483734131, "count": 1, "min": 8150.918483734131, "max": 8150.918483734131}}}
#
# #metrics {"StartTime": 1627919600.8355756, "EndTime": 1627919600.8443127, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 1.8434524536132812, "count": 1, "min": 1.8434524536132812, "max": 1.8434524536132812}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# #metrics {"StartTime": 1627919592.4850276, "EndTime": 1627919600.835462, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"evaluate.time": {"sum": 8150.918483734131, "count": 1, "min": 8150.918483734131, "max": 8150.918483734131}}}
#
# #metrics {"StartTime": 1627919600.8355756, "EndTime": 1627919600.8443127, "Dimensions": {"Algorithm": "RandomCutForestModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 1.8434524536132812, "count": 1, "min": 1.8434524536132812, "max": 1.8434524536132812}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# CPU times: user 1.81 s, sys: 148 ms, total: 1.96 s
# Wall time: 14min 11s

# %% [markdown]
# #### Downloading Prediction Scores to Local Directory

# %%
boto3.resource("s3").meta.client.download_file(
    BUCKET, f"{PREFIX}/pred/X_valid.csv.out", os.path.join(DATA_DIR, "X_valid.csv.out")
)
rcf_scores = (
    pd.read_csv(os.path.join(DATA_DIR, "X_valid.csv.out"), header=None)[0]
    .map(lambda x: eval(x)["score"])
    .values
)

# %% [markdown]
# # Model Evaluation

# %%
charts = []
for model, score in zip(
    ["Isolation Forest", "COPOD", "Random Cut Forest"],
    [if_scores[:, 1], cop_scores[:, 1], rcf_scores],
):
    charts.append(
        plot_histogram(score, model, bins=50, bar_size=15, height=150, n_digits=2)
    )

alt.VConcatChart(vconcat=charts).configure_axisX(labelAngle=-45)
# Out:
# alt.VConcatChart(...)

# %%
roc_curves = [
    x
    for scores in [if_scores[:, 1], cop_scores[:, 1], rcf_scores]
    for x in roc_curve(df_y_valid, scores)
]
aurocs = [
    roc_auc_score(df_y_valid, scores)
    for scores in [if_scores[:, 1], cop_scores[:, 1], rcf_scores]
]

pr_curves = [
    x
    for scores in [if_scores[:, 1], cop_scores[:, 1], rcf_scores]
    for x in precision_recall_curve(df_y_valid, scores)
]
auprcs = [
    average_precision_score(df_y_valid, scores)
    for scores in [if_scores[:, 1], cop_scores[:, 1], rcf_scores]
]

# %%
x = np.linspace(0, 1, int(5000 / 3))
source = np.c_[
    x,
    interp1d(roc_curves[0], roc_curves[1])(x),
    interp1d(roc_curves[3], roc_curves[4])(x),
    interp1d(roc_curves[6], roc_curves[7])(x),
]
columns = [
    f"IF (AUROC:{aurocs[0]:0.2%})",
    f"COPOD (AUROC:{aurocs[1]:0.2%})",
    f"RCF (AUROC:{aurocs[2]:0.2%})",
]
source = pd.DataFrame(source, columns=["x"] + columns)
source = pd.melt(source, id_vars=["x"], value_vars=columns)

highlight = alt.selection(
    type="single", on="mouseover", fields=["variable"], nearest=True
)
base = alt.Chart(source).encode(
    x=alt.X("x:Q", title="False Positive Rate"),
    y=alt.Y("value:Q", title="True Positive Rate"),
    color=alt.Color(
        "variable:N", legend=alt.Legend(title="Estimator", orient="bottom-right")
    ),
)
points = (
    base.mark_circle()
    .encode(opacity=alt.value(0))
    .add_selection(highlight)
    .properties()
)
line = base.mark_line().encode(
    size=alt.condition(~highlight, alt.value(1.5), alt.value(3))
)
(points + line).properties(title="Receiver Operating Characteristic Curves")
# Out:
# alt.LayerChart(...)

# %%
source = np.c_[
    x,
    interp1d(pr_curves[1], pr_curves[0])(x),
    interp1d(pr_curves[4], pr_curves[3])(x),
    interp1d(pr_curves[7], pr_curves[6])(x),
]
columns = [
    f"IF (AUPRC:{auprcs[0]:0.2%})",
    f"COPOD (AUPRC:{auprcs[1]:0.2%})",
    f"RCF (AUPRC:{auprcs[2]:0.2%})",
]
source = pd.DataFrame(source, columns=["x"] + columns)
source = pd.melt(source, id_vars=["x"], value_vars=columns)

highlight = alt.selection(
    type="single", on="mouseover", fields=["variable"], nearest=True
)
base = alt.Chart(source).encode(
    x=alt.X("x:Q", title="Recall"),
    y=alt.Y("value:Q", title="Precision", scale=alt.Scale(domain=[0.0, 1.0])),
    color=alt.Color(
        "variable:N", legend=alt.Legend(title="Estimator", orient="top-right")
    ),
)
points = (
    base.mark_circle()
    .encode(opacity=alt.value(0))
    .add_selection(highlight)
    .properties()
)
lines = base.mark_line().encode(
    size=alt.condition(~highlight, alt.value(1.5), alt.value(3))
)
(points + lines).properties(title="Precision - Recall Curves")
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # Model Re-training
# ## Data Preprocessing, Fitting and Prediction

# %%
X_train = transformer.fit_transform(df_train[all_features])
X_test = transformer.transform(df_test[all_features])

# %%
# %%time
_ = cop_estimator.fit(X_train)
cop_scores = cop_estimator.predict_proba(X_test)
# Out:
# CPU times: user 5min 51s, sys: 2min 49s, total: 8min 40s
# Wall time: 8min 19s

# %%
submission = pd.DataFrame(
    {"TransactionID": df_test["TransactionID"].values, "isFraud": cop_scores[:, 1]}
)
submission.to_csv("./submission.csv", index=False)
